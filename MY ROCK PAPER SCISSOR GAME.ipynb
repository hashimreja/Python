# %%
'''
author @hashimreja syed
email: hashimreja2@gmail.com
rules: enter the characters in lower format
'''
import random
computerscore = 0
humanscore = 0
tie = 0
while True:
    user = input('enter rock or paper or scissor: ')
    computer = random.choice(['rock','paper','scissors'])
    if user == 'rock' and computer == 'rock':
        tie += 1
        print('the  match is tied and tie score is {} '.format(tie))
        continue
    else:
        pass
    if user == 'paper' and computer == 'paper':
        tie += 1
        print('the match is tied tie score is {} '.format(tie))
        continue
    else:
        pass
    if user == 'scissors' and computer == 'scissors':
        tie += 1
        print('the match is tied tie score is {} '.format(tie))
        continue
    else:
        pass
    if user == 'rock' and computer == 'paper':
        humanscore +=1
        print('you won score is {} '.format(humanscore))
        continue
    else:
        pass
    if user == 'rock' and computer == 'scissor':
        humanscore += 1
        print('you won score is {} '.format(humanscore) )
        continue
    else:
        pass
    if user == 'paper' and computer == 'rock':
        computerscore += 1
        print('computer won score is {} '.format(computerscore))
        continue
    else:
        pass
    if user == 'paper' and computer == 'scissor':
        computerscore += 1
        print('computer won score is {} '.format(computerscore))
        continue
    else:
        pass
    if user == 'scissor' and computer == 'rock':
        
            computerscore += 1
            print('computer won score is {} '.format(computerscore))
            continue
    else:
        pass
    if user == 'scissor' and computer == 'paper':
        humanscore += 1
        print('you won score is {} '.format(humanscore))
        continue
    else:
        pass
# Out:
# enter rock or paper or scissor: rock
# enter rock or paper or scissor: paper
# computer won score is 1
# enter rock or paper or scissor: rock
# the  match is tied and tie score is 1
# enter rock or paper or scissor: rock
# the  match is tied and tie score is 2
# enter rock or paper or scissor: paper
# computer won score is 2
# enter rock or paper or scissor: paper
# computer won score is 3
# enter rock or paper or scissor: rock
# enter rock or paper or scissor: scissor
# you won score is 1
# enter rock or paper or scissor: scissor
# you won score is 2
# enter rock or paper or scissor: scissor
# computer won score is 4
# enter rock or paper or scissor: scissor
# computer won score is 5
# enter rock or paper or scissor: scissor
# computer won score is 6
# enter rock or paper or scissor: scissor
# you won score is 3
# enter rock or paper or scissor: scissor
# computer won score is 7
# enter rock or paper or scissor: scissor
# computer won score is 8
